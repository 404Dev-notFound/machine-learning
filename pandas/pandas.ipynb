# %% [markdown]
# # Introduction to Pandas
#
# ## what is pandas?
#
# A powerful library for data manipulation and analysis in Python. Built on top of NumPy, provides data structures like Series and DataFrame.
#
# ## why use Pandas?
#
# --> Easy data cleaning and transformation.
#
# --> Efficient handling of large datasets.
#
# --> Integration with other Pandas libraries like Matplotlib and Seaborn for visualization.

# %%
print("Introduction to Pandas")
# Out:
# Introduction to Pandas

# %%
# !conda install pandas
# Out:
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# # All requested packages already installed.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.3.1
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %% [markdown]
# ### Key Data Dtructures in Pandas
#
# -->Series
#
# -->DataFrame

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,2,3,4,5] , index=['a','b','c','d','e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
plt.plot(s)

# %%
# df = pd.DataFrame({
#     "names": ["Dev", "rohan", "shubham"],
#     "marks": [100, 53, 45]
# })
# df

# %%
# !pip install openpyxl
# !pip install xlrd
# !pip install --upgrade --force-reinstall xlrd
# Out:
# ...
#   Using cached xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Using cached xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# ...
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.2
#     Uninstalling xlrd-2.0.2:
#       Successfully uninstalled xlrd-2.0.2
# ...

# %%
df = pd.read_excel("iris.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df = pd.read_excel("iris.xlsx")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...
